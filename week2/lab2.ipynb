# %% [markdown]
# Lab 2.1: Number Classifier
# ○ Objective: Students will write a script to classify a user-provided integer as positive,
# negative, or zero, and also check if it's even or odd.

# %%
num = int(input("Enter a number: "))

if num > 0:
    sign = "บวก"
elif num < 0:
    sign = "ลบ"
else:
    sign = "ศูนย์"

if num % 2 == 0:
    parity = "คู่"
else:
    parity = "คี่"

print(f"ตรวจสอบเลข {num} เป็น {sign}")
print(f"เลข {num} เป็นเลข {parity}")
print(f"{num} ผลลัพธ์เป็น{sign} และเป็นเลข {parity}")
# Out:
# 20 is positive and even number.

# %% [markdown]
# Lab 2.2

# %%
age = int(input("Enter your age: "))

if age < 5:
    print("You're too young for movies! Enjoy cartoons.") 
elif age <= 12:
    print("G-rated or PG-rated movies.")
elif age <= 17:
    print("PG-13 or R-rated (with parental guidance).") 
else:
    print("Any movie rating.")
    

    like = input("Do you like action movies? (yes/no): ").strip().lower()
    if like == "yes":
        print("You might enjoy the latest action blockbuster!")

# %% [markdown]
# activity 2.1
#
# Block A: Evaluation Check
#
# temp = 25
# is_raining = True
#
# if temp > 20 and not is_raining:
#
#     print("Perfect day for a picnic!")
#
# elif temp <= 20 or is_raining:
#
#     print("Stay indoors or bring an umbrella.")
#
# else:
#
#     print("Unsure about the weather.")
#
#
# ลำดับการทำงาน:
#
# กำหนดค่า temp = 25 และ is_raining = True
# เช็คเงื่อนไขแรก if temp > 20 and not is_raining:
#
# temp > 20 → 25 > 20 → True
# not is_raining → not True → False
# True and False → False
# เงื่อนไขนี้เป็นเท็จ ข้ามไปเช็คเงื่อนไขถัดไป
#
#
# เช็คเงื่อนไข elif temp <= 20 or is_raining:
#
# temp <= 20 → 25 <= 20 → False
# is_raining → True
# False or True → True
# เงื่อนไขนี้เป็นจริง รันคำสั่งใน block นี้ และไม่ไปเช็ค else
#
# output
#
# Stay indoors or bring an umbrella.

# %% [markdown]
# activity 2.1
#
# Block B: Vectorized Filter
#
# phrase = "Python 2026 Engine"
#
# consonants = {c.lower() for c in phrase if c.isalpha() and c.lower() not in 'aeiou'}
#
# print(f"Unique consonants: {consonants}")
#
# ลำดับการทำงาน:
#
# phrase คือสตริง "Python 2026 Engine"
# ใช้ set comprehension วนทุกตัวอักษร c ใน phrase
# เงื่อนไขคัดกรอง 2 ชั้น:
#
# c.isalpha() → เก็บเฉพาะตัวอักษร (ตัด ตัวเลข 2026 และ ช่องว่าง ออก)
# c.lower() not in 'aeiou' → ตัดสระ (a, e, i, o, u) ออก ทั้งตัวพิมพ์เล็ก/ใหญ่
#
#
# ตัวที่เหลือผ่านการแปลงเป็นตัวพิมพ์เล็กด้วย c.lower() แล้วเก็บลงใน set (set จะไม่มีค่าซ้ำกันอัตโนมัติ)
# ตัวอักษรใน "Python 2026 Engine" ที่เป็นพยัญชนะ (ไม่ซ้ำ หลัง lower) คือ: p, t, h, n, g, e... แต่ e เป็นสระจะถูกตัดออก เหลือ: p, t, h, n, g
#
# output
# Unique consonants: {'p', 't', 'h', 'n', 'g'}

# %% [markdown]
# activity 2.2
#
# print("เดินเข้าไปในป่าลึกและพบทางแยก 2 ทาง")
#
# print("1. เดินไปทางซ้าย (มีแม่น้ำ)")
#
# print("2. เดินไปทางขวา (มีถ้ำมืด)")
#
# choice1 = input("เลือกทาง (1 หรือ 2): ")
#
# if choice1 == "1":
#     print("เจอแม่น้ำ มีเรือเล็กลำหนึ่งจอดอยู่")
#
#     print("1. ขึ้นเรือข้ามแม่น้ำ")
#
#     print("2. เดินตามแม่น้ำต่อไป")
#
#     choice2 = input("เลือกทาง (1 หรือ 2): ")
#
#     if choice2 == "1":
#         print("เรือพลิกคว่ำกลางแม่น้ำ แต่ว่ายน้ำกลับฝั่งได้สำเร็จ แต่ของหายหมด")
#     elif choice2 == "2":
#         print("เจอหมู่บ้านชาวประมงและได้พักค้างคืนอย่างปลอดภัย")
#     else:
#         print("ยืนงงอยู่ริมแม่น้ำจนค่ำ")
#
# elif choice1 == "2":
#     print("เดินเข้าไปในถ้ำมืด ได้ยินเสียงคำรามแปลก ๆ")
#
#     print("1. จุดคบไฟแล้วเดินต่อไป")
#
#     print("2. วิ่งกลับออกจากถ้ำทันที")
#
#     choice2 = input("เลือกทาง (1 หรือ 2): ")
#
#     if choice2 == "1":
#         print("เจอสมบัติโบราณ แต่ต้องหนีหมีถ้ำกลับออกมา")
#     elif choice2 == "2":
#         print("ปลอดภัย แต่ไม่ได้สำรวจอะไรเลย ")
#     else:
#         print("คุณลังเลจนไฟฉายแบตหมด ต้องเดินคลำในที่มืด")
#
# else:
#     print("คุณยืนนิ่งอยู่ที่ทางแยกจนพระอาทิตย์ตก")
